# %% [markdown]
# ### Geek for Geeks Web Scrapping

# %%
#This will work in Google Colab Python 2.
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#Change the Directory to gdrive so that you get the html file in there.
# %cd content
# %cd gdrive
# %cd My Drive
# !ls

# %%
import requests

from os import system
from sys import exit
from time import sleep
from requests.exceptions import ConnectionError

from bs4 import BeautifulSoup

class Article(object):
    """ This Class Contains the title and the content of the article.
    The title can be use as key to the article link for the navigation purpose. """

    def __init__(self, title, content):
        self.title = title
        self.content = content


BASE_URL = 'http://www.geeksforgeeks.org/'
articles = []

CHOICE_TO_CATEGORY_MAPPING = {
    1: 'c',
    2: 'c-plus-plus',
    3: 'java',
    4: 'python',
    5: 'fundamentals-of-algorithms',
    6: 'data-structures'
}


def display_menu():
    print("Choose category to scrape: ")
    print("1. C Language")
    print("2. C++ Language")
    print("3. Java")
    print("4. Python")
    print("5. Algorithms")
    print("6. Data Structures")


def get_category_choice():
    choice = int(raw_input("Enter choice: "))
    try:
        category_url = CHOICE_TO_CATEGORY_MAPPING[choice]
    except KeyError:
        print("Wrong Choice Entered. Exiting!")
        exit(1)
    return category_url


def save_articles_as_html_and_pdf():
    print("All links scraped, extracting articles")
    # Formatting the html for articles
    all_articles = (
        '<!DOCTYPE html>'
        '<html><head>'
        '<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />'
        '<link rel="stylesheet" href="style.min.css" type="text/css" media="all" />'
        '<script src="https://cdn.rawgit.com/google/code-prettify/master/loader/run_prettify.js"></script>'
        '</head><body>'
    )

    all_articles += '<h1 style="text-align:center;font-size:40px">' + \
                    category_url.title() + ' Archive</h1><hr>'
    all_articles += '<h1 style="padding-left:5%;font-size:200%;">Index</h1><br/>'

    for x in range(len(articles)):
        all_articles += '<a href =\"#' + str(x+1) + '\">' + \
                        '<h1 style="padding-left:5%;font-size:20px;">' + \
                        str(x+1) + ".\t\t"+articles[x].title + '</h1></a> <br/>'
    for x in range(len(articles)):
        all_articles += '<hr id=\"' + str(x+1) +'\">' + articles[x].content.decode("utf-8")

    all_articles += '''</body></html>'''
    html_file_name = 'G4G_' + category_url.title() + '.html'
    html_file = open(html_file_name, "w")
    html_file.write(all_articles.encode("utf-8"))
    html_file.close()

    pdf_file_name = 'G4G_' + category_url.title() + '.pdf'
    print("Generating PDF " + pdf_file_name)
    html_to_pdf_command = 'wkhtmltopdf ' + html_file_name + ' ' + pdf_file_name
    system(html_to_pdf_command)


def scrape_category(category_url):
    print BASE_URL + category_url;
    try:
        soup = BeautifulSoup(requests.get(BASE_URL + category_url).text)
    except ConnectionError:
        print("Couldn't connect to Internet! Please check your connection & Try again.")
        exit(1)

    # Selecting links which are in the category page
    links = [a.attrs.get('href') for a in soup.select('article li a')]
    # Removing links for the categories with anchor on same page
    links = [link for link in links if not link.startswith('#')]

    print("Found: " + str(len(links)) + " links")
    i = 1
    a=[]
    
    # Traverse each link to find article and save it.
    for link in links:
        
       if "http://www.geeksforgeeks.org/" in link: 
        try:
            if i % 10 == 0:
                sleep(5)  # Sleep for 5 seconds before scraping every 10th link
            link = link.strip()
            print("Scraping link no: " + str(i) + " Link: " + link)
            i += 1
            link_soup = BeautifulSoup(requests.get(link).text)
            # Remove the space occupied by Google Ads (Drop script & ins node)
            [script.extract() for script in link_soup(["script", "ins"])]
            for code_tag in link_soup.find_all('pre'):
                code_tag['class'] = code_tag.get('class', []) + ['prettyprint']
            article = link_soup.find('article')
            # Now add this article to list of all articles
           
            page = Article(title=link_soup.title.string, content=article.encode('UTF-8'))
            articles.append(page)
        # Sometimes hanging. So Ctrl ^ C, and try the next link.
        # Find out the reason & improve this.
        except KeyboardInterrupt:
            continue
        except ConnectionError:
            print("Internet disconnected! Please check your connection & Try again.")
            if articles:
                print("Making PDF of links scraped till now.")
                break
            else:
                exit(1)


if __name__ == '__main__':
    display_menu()
    category_url = get_category_choice()
    scrape_category(category_url)
    save_articles_as_html_and_pdf()
# Out:
# Choose category to scrape:
# 1. C Language
# 2. C++ Language
# 3. Java
# 4. Python
# 5. Algorithms
# 6. Data Structures
# http://www.geeksforgeeks.org/c-plus-plus
# Found: 478 links
# Scraping link no: 1 Link: http://www.geeksforgeeks.org/setting-c-development-environment/
# Scraping link no: 2 Link: http://www.geeksforgeeks.org/writing-first-c-program-hello-world-example/
# Scraping link no: 3 Link: http://www.geeksforgeeks.org/fine-write-void-main-cc/
# Scraping link no: 4 Link: http://www.geeksforgeeks.org/c-data-types/
# Scraping link no: 5 Link: http://www.geeksforgeeks.org/basic-input-output-c/
# Scraping link no: 6 Link: http://www.geeksforgeeks.org/cc-preprocessors/
# Scraping link no: 7 Link: http://www.geeksforgeeks.org/operators-c-c/
# Scraping link no: 8 Link: http://www.geeksforgeeks.org/loops-in-c
# Scraping link no: 9 Link: http://www.geeksforgeeks.org/decision-making-c-c-else-nested-else/
# Scraping link no: 10 Link: http://www.geeksforgeeks.org/execute-else-statements-cc-simultaneously/
# Scraping link no: 11 Link: http://www.geeksforgeeks.org/switch-statement-cc/
# Scraping link no: 12 Link: http://www.geeksforgeeks.org/functions-in-c/
# Scraping link no: 13 Link: http://www.geeksforgeeks.org/arrays-in-c-language-set-1-introduction/
# Scraping link no: 14 Link: http://www.geeksforgeeks.org/c-string-class-and-its-applications/
# Scraping link no: 15 Link: http://www.geeksforgeeks.org/pointers-in-c-and-c-set-1-introduction-arithmetic-and-array/
# Scraping link no: 16 Link: http://www.geeksforgeeks.org/references-in-c/
# Scraping link no: 17 Link: http://www.geeksforgeeks.org/basic-concepts-of-object-oriented-programming-using-c/
# Scraping link no: 18 Link: http://www.geeksforgeeks.org/write-c-program-wont-compiler-c/
# Scraping link no: 19 Link: http://www.geeksforgeeks.org/extern-c-in-c/
# Scraping link no: 20 Link: http://www.geeksforgeeks.org/g-fact-12-2/
# Scraping link no: 21 Link: http://www.geeksforgeeks.org/write-c-program-produce-different-result-c/
# Scraping link no: 22 Link: http://www.geeksforgeeks.org/g-fact-54/
# Scraping link no: 23 Link: http://www.geeksforgeeks.org/difference-c-structures-c-structures/
# Scraping link no: 24 Link: http://www.geeksforgeeks.org/comparison-of-inheritance-in-c-and-java/
# Scraping link no: 195 Link: http://www.geeksforgeeks.org/random-header-set-2-distributions/
# Scraping link no: 196 Link: http://www.geeksforgeeks.org/array-type-manipulation-in-c/
# Scraping link no: 197 Link: http://www.geeksforgeeks.org/c-program-demonstrate-fork-and-pipe/
# Scraping link no: 198 Link: http://www.geeksforgeeks.org/complex-numbers-c-set-1/
# Scraping link no: 199 Link: http://www.geeksforgeeks.org/complex-numbers-c-set-2/
# Scraping link no: 200 Link: http://www.geeksforgeeks.org/scanf-fscanf-sscanf-scanf_s-fscanf_s-sscanf_s/
# Scraping link no: 201 Link: http://www.geeksforgeeks.org/chrono-in-c/
# Scraping link no: 202 Link: http://www.geeksforgeeks.org/std-valarray-class-c/
# Scraping link no: 203 Link: http://www.geeksforgeeks.org/floating-point-manipulation-math-h/
# Scraping link no: 204 Link: http://www.geeksforgeeks.org/character-classification-c-cctype/
# Scraping link no: 205 Link: http://www.geeksforgeeks.org/socket-programming-cc/
# Scraping link no: 206 Link: http://www.geeksforgeeks.org/precision-of-floating-point-numbers-in-c-floor-ceil-trunc-round-and-setprecision/
# Scraping link no: 207 Link: http://www.geeksforgeeks.org/bitsstdc-h-c/
# Scraping link no: 208 Link: http://www.geeksforgeeks.org/stdstring-class-in-c/
# Scraping link no: 209 Link: http://www.geeksforgeeks.org/merge-operations-using-stl-in-c-merge-includes-set_union-set_intersection-set_difference/
# Scraping link no: 210 Link: http://www.geeksforgeeks.org/stdpartition-in-c-stl/
# Scraping link no: 211 Link: http://www.geeksforgeeks.org/ratio-manipulations-in-c-set-1-arithmetic/
# Scraping link no: 212 Link: http://www.geeksforgeeks.org/ratio-manipulations-in-c-set-2-comparison/
# Scraping link no: 213 Link: http://www.geeksforgeeks.org/numeric-header-in-c-stl-set-1-accumulate-and-partial_sum/
# Scraping link no: 214 Link: http://www.geeksforgeeks.org/numeric-header-in-c-stl-set-2-adjacent_difference-inner_product-and-iota/
# Scraping link no: 215 Link: http://www.geeksforgeeks.org/bind-function-placeholders-c/
# Scraping link no: 216 Link: http://www.geeksforgeeks.org/array-class-c/
# Scraping link no: 217 Link: http://www.geeksforgeeks.org/tuples-in-c/
# Scraping link no: 218 Link: http://www.geeksforgeeks.org/regex-regular-expression-in-c/
# Scraping link no: 219 Link: http://www.geeksforgeeks.org/common-subtleties-vector-stls/
# Scraping link no: 220 Link: http://www.geeksforgeeks.org/understanding-constexper-specifier-in-c/
# Scraping link no: 221 Link: http://www.geeksforgeeks.org/unordered_multiset-and-its-uses/
# Scraping link no: 222 Link: http://www.geeksforgeeks.org/unordered_multimap-and-its-application/
# Scraping link no: 223 Link: http://www.geeksforgeeks.org/populating-vector-c-using-fill-fill_n/
# Scraping link no: 224 Link: http://www.geeksforgeeks.org/writing-os-independent-code-cc/
# Scraping link no: 225 Link: http://www.geeksforgeeks.org/database-connectivity-using-cc/
# Scraping link no: 226 Link: http://www.geeksforgeeks.org/c-bitset-and-its-application/
# Scraping link no: 227 Link: http://www.geeksforgeeks.org/unordered_map-in-stl-and-its-applications/
# Scraping link no: 228 Link: http://www.geeksforgeeks.org/unorderd_set-stl-uses/
# Scraping link no: 229 Link: http://www.geeksforgeeks.org/g-fact-37-nextafter-nexttoward-c/
# Scraping link no: 230 Link: http://www.geeksforgeeks.org/user-defined-literals-cpp/
# Scraping link no: 231 Link: http://www.geeksforgeeks.org/placement-new-operator-cpp/
# Scraping link no: 232 Link: http://www.geeksforgeeks.org/advanced-c-boost-library/
# Scraping link no: 233 Link: http://www.geeksforgeeks.org/copy-swap-idiom-c/
# Scraping link no: 234 Link: http://www.geeksforgeeks.org/zombie-and-orphan-processes-in-c/
# Scraping link no: 235 Link: http://www.geeksforgeeks.org/lambda-expression-in-c/
# Scraping link no: 236 Link: http://www.geeksforgeeks.org/command-line-arguments-in-c-cpp/
# Scraping link no: 237 Link: http://www.geeksforgeeks.org/writing-cc-code-efficiently-in-competitive-programming/
# Scraping link no: 238 Link: http://www.geeksforgeeks.org/useful-array-algorithms-in-c-stl/
# Scraping link no: 239 Link: http://www.geeksforgeeks.org/data-type-ranges-and-their-macros-in-c/
# Scraping link no: 240 Link: http://www.geeksforgeeks.org/cincout-vs-scanfprintf/
# Scraping link no: 241 Link: http://www.geeksforgeeks.org/getchar_unlocked-faster-input-cc-competitive-programming/
# Scraping link no: 242 Link: http://www.geeksforgeeks.org/c-qsort-vs-c-sort/
# Scraping link no: 243 Link: http://www.geeksforgeeks.org/generating-test-cases-generate-and-generate_n-in-c/
# Scraping link no: 244 Link: http://www.geeksforgeeks.org/g-fact-28/
# Scraping link no: 245 Link: http://www.geeksforgeeks.org/g-fact-24/
# Scraping link no: 246 Link: http://www.geeksforgeeks.org/g-fact-21/
# Scraping link no: 247 Link: http://www.geeksforgeeks.org/can-access-private-data-members-class-without-using-member-friend-function/
# Scraping link no: 248 Link: http://www.geeksforgeeks.org/make-class-whose-objects-can-dynamically-allocated/
# Scraping link no: 249 Link: http://www.geeksforgeeks.org/print-geeksforgeeks-empty-main-c/
# Scraping link no: 250 Link: http://www.geeksforgeeks.org/output-of-c-program-set-18-3/
# Scraping link no: 251 Link: http://www.geeksforgeeks.org/how-to-restrict-dynamic-allocation-of-objects-in-c/
# Scraping link no: 252 Link: http://www.geeksforgeeks.org/how-can-we-sum-the-digits-of-a-given-number-in-single-statement/
# Scraping link no: 253 Link: http://www.geeksforgeeks.org/writing-url-c-program/
# Scraping link no: 254 Link: http://www.geeksforgeeks.org/creative-c-program-zoom-digits-integer/
# Scraping link no: 255 Link: http://www.geeksforgeeks.org/programs-printing-pyramid-patterns-c/
# Scraping link no: 256 Link: http://www.geeksforgeeks.org/how-to-swap-two-variables-in-one-line/
# Scraping link no: 257 Link: http://www.geeksforgeeks.org/cc-program-shutdown-system/
# Scraping link no: 258 Link: http://www.geeksforgeeks.org/cc-programs/
# Scraping link no: 259 Link: http://www.geeksforgeeks.org/category/cpp/
# Scraping link no: 260 Link: http://www.geeksforgeeks.org/c-programming-multiple-choice-questions/
# All links scraped, extracting articles
# Generating PDF G4G_C-Plus-Plus.pdf

# %%
# !ls
